# %%
import pandas as pd
df = pd.read_csv("./dh_dataset.csv")
df[["Reading_Time_Minutes"]].hist(bins=100)
# Out:
# array([[<Axes: title={'center': 'Reading_Time_Minutes'}>]], dtype=object)

# %%
import pandas as pd
df = pd.read_csv("./dh_dataset.csv")
df[["Institution_Type"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Institution_Type'>
