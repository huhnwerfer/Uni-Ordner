# %%
import pandas as pd
df = pd.read_csv("./dh_dataset.csv", delimiter=",")
df
# Out:
#      Reading_Time_Minutes  Visitors_Per_Day  Engagement_Index  \
# 0               32.590154        176.610337         10.604403
# 1               29.734750        113.939508         10.816959
# 2               33.823813        640.981978         10.634793
# 3               37.876452        709.527535          9.382399
# 4               29.365338         41.401516          8.436866
# ..                    ...               ...               ...
# 995             29.426541        288.331816          6.949770
# 996                   NaN        214.955260          9.274960
# 997             34.038040        521.563742          9.595771
# 998             28.066385         16.009768          5.143425
# 999             33.342022         18.509090         10.764208
#
#      Digitization_Progress  Metadata_Accuracy Institution_Type   Project_Type  \
# 0                 2.183195          95.703718       University  Visualization
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reading_Time_Minutes   916 non-null    float64
#  1   Visitors_Per_Day       907 non-null    float64
#  2   Engagement_Index       909 non-null    float64
#  3   Digitization_Progress  913 non-null    float64
#  4   Metadata_Accuracy      919 non-null    float64
#  5   Institution_Type       1000 non-null   object
#  6   Project_Type           1000 non-null   object
#  7   Region                 1000 non-null   object
#  8   Time_Period_Focus      1000 non-null   object
#  9   Primary_Tool_Used      1000 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#        Reading_Time_Minutes  Visitors_Per_Day  Engagement_Index  \
# count            916.000000        907.000000        909.000000
# mean              30.677895        508.594423          9.052507
# std                4.884249        287.106136          1.446502
# min               16.880834         13.484628          0.932002
# 25%               27.455757        253.018148          8.447325
# 50%               30.669798        521.563742          9.449784
# 75%               33.812331        751.502781         10.051761
# max               50.122159        999.455570         10.978373
#
#        Digitization_Progress  Metadata_Accuracy
# count             913.000000         919.000000
# mean                1.966338          95.480039
# std                 1.550292           0.577742
# min                 0.069253          93.775472
# 25%                 0.934845          95.089883
# 50%                 1.540272          95.476660
# 75%                 2.514474          95.881489
# ...

# %%
df[["Reading_Time_Minutes","Institution_Type","Primary_Tool_Used"]].head(5)
# Out:
#    Reading_Time_Minutes Institution_Type Primary_Tool_Used
# 0             32.590154       University      Voyant Tools
# 1             29.734750       University      Voyant Tools
# 2             33.823813          Library            Python
# 3             37.876452           Museum            Python
# 4             29.365338           Museum      Voyant Tools

# %% [markdown]
# # Group Exercise
#
# Each group gets two columns assigned. Each group should plot a histogram for each column and report the following properties:
#
# Skewness, Median, Mean, Mode and additional obervations!
#
# Also think about missing values. Calculate the proportion of them and reflect the influence of them missing.
#
# - Gr. 1: Reading_Time_Minutes, Institution_Type
# - Gr. 2: Visitors_Per_Day, Project_Type
# - Gr. 3: Engagement_Index, Region
# - Gr. 4: Digitization_Progress, Time_Period_Focus
# - Gr. 5: Metadata_Accuracy, Primary_Tool_Used
#
#
# Rule of thumb Skewness
# - Right-skewed (positive skew): mod < med < average
# - symmetrical: mod = med = average
# - Left-skewed (negative skew): mod > med > average
#
# ![Skewness](https://miro.medium.com/v2/resize:fit:846/1*XU3Kdl521XnWHECHZ7XOaQ.jpeg)
